# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (1.3.9)
# Requirement already satisfied: affine in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (1.26.4)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from rasterio) (69.2.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /Users/kangbeenko/opt/anaconda3/envs/tf215_py311/lib/python3.11/site-packages (from snuggs>=1.4.1->rasterio) (3.1.2)

# %%
import os
import warnings
warnings.filterwarnings("ignore")
import glob
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.python.keras import backend as K
import sys
import pandas as pd
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator
import threading
import random
import rasterio
import os
import numpy as np
import sys
from sklearn.utils import shuffle as shuffle_lists
from keras.models import *
from keras.layers import *
import numpy as np
from keras import backend as K
from sklearn.model_selection import train_test_split
import joblib
# Out:
# 2024-03-19 12:25:55.501967: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-19 12:25:55.527276: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-19 12:25:55.527315: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-19 12:25:55.527973: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-19 12:25:55.532235: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Unet 모델 정의
def attention_gate(input_x, g, inter_channel):
    # input_x: 스킵 연결로부터의 입력
    # g: 현재 레이어의 입력
    # inter_channel: 내부 채널 수 (필터의 수)

    #input_x => 256, 256, 16

    theta_x = Conv2D(inter_channel, kernel_size=2, strides=2, padding='same')(input_x)
    # theta_x => 128, 128, 16

    # g => 128, 128, 32

    phi_g = Conv2D(inter_channel, kernel_size=1, padding='same')(g)
    # phi_g => 128, 128, 16

    f = Activation('relu')(add([theta_x, phi_g]))

    # f 128 128 16
    psi_f = Conv2D(1, kernel_size=1, padding='same')(f)
    # print(psi_f.shape)

    rate = Activation('sigmoid')(psi_f)

    upsampled_rate = UpSampling2D(size=(2, 2))(rate)
    attended = multiply([input_x, upsampled_rate])
    return attended

def conv2d_block(input_tensor, n_filters, kernel_size=5, batchnorm=True):
    # 기존 conv2d_block 구현을 재사용합니다.
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def get_attention_unet(input_height=256, input_width=256, n_filters=16, dropout=0.1, batchnorm=True, n_channels=10, nClasses=1):
    input_img = Input(shape=(input_height, input_width, n_channels))

    # U-Net의 인코더 부분
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size=5, batchnorm=batchnorm)
    # 256 256 16
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    print(p1.shape)

    c2 = conv2d_block(p1, n_filters * 2, kernel_size=5, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    print(p2.shape)
    
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size=5, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size=5, batchnorm=batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    print(c4.shape)

    c5 = conv2d_block(p4, n_filters * 16, kernel_size=5, batchnorm=batchnorm)
    print(c5.shape)
    # p5 = MaxPooling2D((2, 2))(c5)
    # p5 = Dropout(dropout)(p5)
    # print(c5.shape)
    
    # Attention Gate 적용
    g4 = attention_gate(c4, c5, n_filters * 8)
    up4 = Conv2DTranspose(n_filters*8, (5,5), strides=(2,2), padding='same')(c5)
    up4 = concatenate([up4, g4])
    c6 = conv2d_block(up4, n_filters * 8, kernel_size=5, batchnorm=batchnorm)
    
    g3 = attention_gate(c3, c6, n_filters * 4)
    up3 = Conv2DTranspose(n_filters*4, (5,5), strides=(2,2), padding='same')(c6)
    up3 = concatenate([up3, g3])
    c7 = conv2d_block(up3, n_filters * 4, kernel_size=5, batchnorm=batchnorm)

    g2 = attention_gate(c2, c7, n_filters * 2)
    up2 = Conv2DTranspose(n_filters*2, (5,5), strides=(2,2), padding='same')(c7)
    up2 = concatenate([up2, g2])
    c8 = conv2d_block(up2, n_filters * 2, kernel_size=5, batchnorm=batchnorm)

    g1 = attention_gate(c1, c8, n_filters * 1)
    up1 = Conv2DTranspose(n_filters*1, (5,5), strides=(2,2), padding='same')(c8)
    up1 = concatenate([up1, g1])
    c9 = conv2d_block(up1, n_filters * 1, kernel_size=5, batchnorm=batchnorm)
    
    output_img = Conv2D(nClasses, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[output_img])

    return model

# 모델 생성
model = get_attention_unet(input_height=256, input_width=256, n_filters=16, dropout=0.1, batchnorm=True, n_channels=10, nClasses=1)
model.summary()
# Out:
# 2024-03-19 12:29:37.131590: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 881 MB memory:  -> device: 0, name: NVIDIA L40, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2024-03-19 12:29:37.133900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 43020 MB memory:  -> device: 1, name: NVIDIA L40, pci bus id: 0000:21:00.0, compute capability: 8.9
# 2024-03-19 12:29:37.135937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 43020 MB memory:  -> device: 2, name: NVIDIA L40, pci bus id: 0000:41:00.0, compute capability: 8.9
# 2024-03-19 12:29:37.137866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 43020 MB memory:  -> device: 3, name: NVIDIA L40, pci bus id: 0000:61:00.0, compute capability: 8.9
# 2024-03-19 12:29:37.139760: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 43020 MB memory:  -> device: 4, name: NVIDIA L40, pci bus id: 0000:81:00.0, compute capability: 8.9
# 2024-03-19 12:29:37.141620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 43020 MB memory:  -> device: 5, name: NVIDIA L40, pci bus id: 0000:a1:00.0, compute capability: 8.9
# 2024-03-19 12:29:37.143577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 43020 MB memory:  -> device: 6, name: NVIDIA L40, pci bus id: 0000:c1:00.0, compute capability: 8.9
# 2024-03-19 12:29:37.145445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 43020 MB memory:  -> device: 7, name: NVIDIA L40, pci bus id: 0000:e1:00.0, compute capability: 8.9
# (None, 128, 128, 16)
# (None, 64, 64, 32)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 10)]       0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         4016      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 16)         64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 16)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         6416      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 16)         64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 16)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['activation_1[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 128, 128, 16)         0         ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         12832     ['dropout[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 128, 32)         128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         25632     ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 32)         128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_3[0][0]']
#  g2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 32)           0         ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           51264     ['dropout_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           102464    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['activation_5[0][0]']
#  g2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)           0         ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)          204928    ['dropout_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 128)          512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          409728    ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 128)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['activation_7[0][0]']
#  g2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)          0         ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          819456    ['dropout_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 16, 16, 256)          1024      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          1638656   ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 256)          1024      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 128)          65664     ['activation_7[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)          32896     ['activation_9[0][0]']
#
#  add (Add)                   (None, 16, 16, 128)          0         ['conv2d_10[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  activation_10 (Activation)  (None, 16, 16, 128)          0         ['add[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 1)            129       ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 16, 16, 1)            0         ['conv2d_12[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 1)            0         ['activation_11[0][0]']
#  D)
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 128)          819328    ['activation_9[0][0]']
#  anspose)
#
#  multiply (Multiply)         (None, 32, 32, 128)          0         ['activation_7[0][0]',
#                                                                      'up_sampling2d[0][0]']
#
#  concatenate (Concatenate)   (None, 32, 32, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'multiply[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)          819328    ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 32, 32, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 128)          409728    ['activation_12[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 32, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 64)           16448     ['activation_5[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 64)           8256      ['activation_13[0][0]']
#
#  add_1 (Add)                 (None, 32, 32, 64)           0         ['conv2d_15[0][0]',
#                                                                      'conv2d_16[0][0]']
#
#  activation_14 (Activation)  (None, 32, 32, 64)           0         ['add_1[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 1)            65        ['activation_14[0][0]']
#
#  activation_15 (Activation)  (None, 32, 32, 1)            0         ['conv2d_17[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 1)            0         ['activation_15[0][0]']
#  g2D)
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 64)           204864    ['activation_13[0][0]']
#  Transpose)
#
#  multiply_1 (Multiply)       (None, 64, 64, 64)           0         ['activation_5[0][0]',
#                                                                      'up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'multiply_1[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 64)           204864    ['concatenate_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 64, 64, 64)           256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 64)           102464    ['activation_16[0][0]']
#
#  batch_normalization_13 (Ba  (None, 64, 64, 64)           256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 32)           4128      ['activation_3[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 32)           2080      ['activation_17[0][0]']
#
#  add_2 (Add)                 (None, 64, 64, 32)           0         ['conv2d_20[0][0]',
#                                                                      'conv2d_21[0][0]']
#
#  activation_18 (Activation)  (None, 64, 64, 32)           0         ['add_2[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 1)            33        ['activation_18[0][0]']
#
#  activation_19 (Activation)  (None, 64, 64, 1)            0         ['conv2d_22[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 1)          0         ['activation_19[0][0]']
#  g2D)
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 32)         51232     ['activation_17[0][0]']
#  Transpose)
#
#  multiply_2 (Multiply)       (None, 128, 128, 32)         0         ['activation_3[0][0]',
#                                                                      'up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'multiply_2[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 128, 128, 32)         51232     ['concatenate_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 128, 128, 32)         128       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 128, 128, 32)         25632     ['activation_20[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128, 128, 32)         128       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 16)         1040      ['activation_1[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 128, 128, 16)         528       ['activation_21[0][0]']
#
#  add_3 (Add)                 (None, 128, 128, 16)         0         ['conv2d_25[0][0]',
#                                                                      'conv2d_26[0][0]']
#
#  activation_22 (Activation)  (None, 128, 128, 16)         0         ['add_3[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 128, 128, 1)          17        ['activation_22[0][0]']
#
#  activation_23 (Activation)  (None, 128, 128, 1)          0         ['conv2d_27[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 1)          0         ['activation_23[0][0]']
#  g2D)
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 16)         12816     ['activation_21[0][0]']
#  Transpose)
#
#  multiply_3 (Multiply)       (None, 256, 256, 16)         0         ['activation_1[0][0]',
#                                                                      'up_sampling2d_3[0][0]']
#
#  concatenate_3 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'multiply_3[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 256, 256, 16)         12816     ['concatenate_3[0][0]']
#
#  batch_normalization_16 (Ba  (None, 256, 256, 16)         64        ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 256, 256, 16)         6416      ['activation_24[0][0]']
#
#  batch_normalization_17 (Ba  (None, 256, 256, 16)         64        ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 256, 256, 1)          17        ['activation_25[0][0]']
#
# ==================================================================================================
# Total params: 6133301 (23.40 MB)
# Trainable params: 6130357 (23.39 MB)
# Non-trainable params: 2944 (11.50 KB)
# __________________________________________________________________________________________________

# %%
# 두 샘플 간의 유사성 metric
def dice_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
    return dice

# 픽셀 정확도를 계산 metric (Keras Backend 사용)
def pixel_accuracy(y_true, y_pred):
    correct_pixels = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    total_pixels = K.sum(K.round(K.clip(y_true, 0, 1)))
    return correct_pixels / total_pixels

tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_23765.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_5710.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_25314.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_32668.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_3361.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_21172.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_7107.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_31361.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_8234.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_28630.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_16906.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_6219.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_339.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_27503.tif
#   inflating: /content/drive/My Drive/Fire Detection Dataset/train_img/train_img_1576.tif

# %%
# 사용할 데이터의 meta정보 가져오기

train_meta = pd.read_csv(f'{destination_folder}train_meta.csv')
test_meta = pd.read_csv(f'{destination_folder}test_meta.csv')

#부분적으로 테스트할 때 사용할 수 있는 코드입니다.
# train_meta = train_meta.iloc[0:101]

# 저장 이름
save_name = 'base_line'

N_FILTERS = 16 # 필터수 지정
N_CHANNELS = 3 # channel 지정
EPOCHS = 300 # 훈련 epoch 지정
BATCH_SIZE = 256 # batch size 지정
IMAGE_SIZE = (256, 256) # 이미지 크기 지정
MODEL_NAME = 'attention_unet' # 모델 이름
RANDOM_STATE = 42 # seed 고정
INITIAL_EPOCH = 0 # 초기 epoch

# 데이터 위치
IMAGES_PATH = f'{destination_folder}train_img/'
MASKS_PATH = f'{destination_folder}train_mask/'

# 가중치 저장 위치
OUTPUT_DIR = f'{destination_folder}train_output/'
WORKERS = 4

# 조기종료
EARLY_STOP_PATIENCE = 5

# 중간 가중치 저장 이름
CHECKPOINT_PERIOD = 5
CHECKPOINT_MODEL_NAME = 'checkpoint-{}-{}-epoch_{{epoch:02d}}.hdf5'.format(MODEL_NAME, save_name)

# 최종 가중치 저장 이름
FINAL_WEIGHTS_OUTPUT = 'model_{}_{}_final_weights.h5'.format(MODEL_NAME, save_name)

# 사용할 GPU 이름
CUDA_DEVICE = 3


# 저장 폴더 없으면 생성
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)


# GPU 설정
os.environ["CUDA_VISIBLE_DEVICES"] = str(CUDA_DEVICE)
try:
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.compat.v1.Session(config=config)
    K.set_session(sess)
except:
    pass

try:
    np.random.bit_generator = np.random._bit_generator
except:
    pass


# train : val = 8 : 2 나누기
x_tr, x_val = train_test_split(train_meta, test_size=0.2, random_state=RANDOM_STATE)
print(len(x_tr), len(x_val))
# Out:
# 26860 6715
# 2024-03-19 12:35:35.326801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 881 MB memory:  -> device: 0, name: NVIDIA L40, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2024-03-19 12:35:35.328423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 43020 MB memory:  -> device: 1, name: NVIDIA L40, pci bus id: 0000:21:00.0, compute capability: 8.9
# 2024-03-19 12:35:35.330022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 43020 MB memory:  -> device: 2, name: NVIDIA L40, pci bus id: 0000:41:00.0, compute capability: 8.9
# 2024-03-19 12:35:35.331594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 43020 MB memory:  -> device: 3, name: NVIDIA L40, pci bus id: 0000:61:00.0, compute capability: 8.9
# 2024-03-19 12:35:35.333112: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 43020 MB memory:  -> device: 4, name: NVIDIA L40, pci bus id: 0000:81:00.0, compute capability: 8.9
# 2024-03-19 12:35:35.334652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 43020 MB memory:  -> device: 5, name: NVIDIA L40, pci bus id: 0000:a1:00.0, compute capability: 8.9
# 2024-03-19 12:35:35.336281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 43020 MB memory:  -> device: 6, name: NVIDIA L40, pci bus id: 0000:c1:00.0, compute capability: 8.9
# 2024-03-19 12:35:35.337846: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 43020 MB memory:  -> device: 7, name: NVIDIA L40, pci bus id: 0000:e1:00.0, compute capability: 8.9

# %%
from keras import layers

MAX_PIXEL_VALUE = 65535 # 이미지 정규화를 위한 픽셀 최대값

# Define the data augmentation
data_augmentation = keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.4),
])


class threadsafe_iter:
    """
    데이터 불러올떼, 호출 직렬화
    """
    def __init__(self, it):
        self.it = it
        self.lock = threading.Lock()

    def __iter__(self):
        return self

    def __next__(self):
        with self.lock:
            return self.it.__next__()


def threadsafe_generator(f):
    def g(*a, **kw):
        return threadsafe_iter(f(*a, **kw))

    return g

def get_img_arr(path):
    img = rasterio.open(path).read().transpose((1, 2, 0))
    img = np.float32(img)/MAX_PIXEL_VALUE

    return img



def get_img_762bands(path):
    img = rasterio.open(path).read((7,6,2)).transpose((1, 2, 0))
    img = np.float32(img)/MAX_PIXEL_VALUE

    return img

def get_mask_arr(path):
    img = rasterio.open(path).read().transpose((1, 2, 0))
    seg = np.float32(img)
    return seg





# from tensorflow.keras.preprocessing.image import img_to_array, array_to_img

@threadsafe_generator
def generator_from_lists(images_path, masks_path, batch_size=32, shuffle=True, random_state=None, image_mode='10bands'):
    images = []
    masks = []

    fopen_image = get_img_arr
    fopen_mask = get_mask_arr

    if image_mode == '762':
        fopen_image = get_img_762bands

    i = 0
    while True:
        if shuffle:
            if random_state is None:
                # Assuming shuffle_lists is a custom function that shuffles the paths in unison
                images_path, masks_path = shuffle_lists(images_path, masks_path)
            else:
                images_path, masks_path = shuffle_lists(images_path, masks_path, random_state=random_state + i)
                i += 1

        for img_path, mask_path in zip(images_path, masks_path):

          if not os.path.exists(img_path) or not os.path.exists(mask_path):
            continue

          img = fopen_image(img_path)
          mask = fopen_mask(mask_path)

          # Append original data
          images.append(img)
          masks.append(mask)

          # Apply and append augmented data
          aug_img = data_augmentation(img)  # Apply augmentation to the image
          aug_mask = data_augmentation(mask)  # Apply the same augmentation to the mask
          images.append(aug_img)
          masks.append(aug_mask)

          if len(images) >= batch_size:
              yield (np.stack(images), np.stack(masks))
              images = []
              masks = []

        if len(images) > 0:
            yield (np.stack(images), np.stack(masks))
            images = []
            masks = []

# %%
def get_model(model_name, nClasses=1, input_height=256, input_width=256, n_filters = 16, dropout = 0.1, batchnorm = True, n_channels=10):
    # if model_name == 'fcn':
    #     model = FCN
    # elif model_name == 'unet':
    #     model = get_unet
    # elif model_name == 'unet_small':
    #     model = get_unet_small1
    # elif model_name == 'unet_smaller':
    #     model = get_unet_small2
    # elif model_name == 'attention_unet':
    #     model = get_attention_unet
    if model_name == 'attention_unet':
        model = get_attention_unet
    else:
        raise ValueError()

    return model(
            nClasses      = nClasses,
            input_height  = input_height,
            input_width   = input_width,
            n_filters     = n_filters,
            dropout       = dropout,
            batchnorm     = batchnorm,
            n_channels    = n_channels
        )

# %%
# train : val 지정 및 generator
images_train = [os.path.join(IMAGES_PATH, image) for image in x_tr['train_img'] ]
masks_train = [os.path.join(MASKS_PATH, mask) for mask in x_tr['train_mask'] ]

images_validation = [os.path.join(IMAGES_PATH, image) for image in x_val['train_img'] ]
masks_validation = [os.path.join(MASKS_PATH, mask) for mask in x_val['train_mask'] ]

train_generator = generator_from_lists(images_train, masks_train, batch_size=BATCH_SIZE, random_state=RANDOM_STATE, image_mode="762")
validation_generator = generator_from_lists(images_validation, masks_validation, batch_size=BATCH_SIZE, random_state=RANDOM_STATE, image_mode="762")


# model 불러오기
model = get_model(MODEL_NAME, input_height=IMAGE_SIZE[0], input_width=IMAGE_SIZE[1], n_filters=N_FILTERS, n_channels=N_CHANNELS)
model.compile(optimizer=Adam(learning_rate=1e-4), 
              loss='binary_crossentropy', 
              metrics=[dice_coef, pixel_accuracy])
model.summary()


# checkpoint 및 조기종료 설정
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=EARLY_STOP_PATIENCE)
checkpoint = ModelCheckpoint(os.path.join(OUTPUT_DIR, CHECKPOINT_MODEL_NAME), monitor='loss', verbose=1,
save_best_only=True, mode='auto', period=CHECKPOINT_PERIOD)
# Out:
# (None, 128, 128, 16)
# (None, 64, 64, 32)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_62 (Conv2D)          (None, 256, 256, 16)         1216      ['input_3[0][0]']
#
#  batch_normalization_36 (Ba  (None, 256, 256, 16)         64        ['conv2d_62[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_63 (Conv2D)          (None, 256, 256, 16)         6416      ['activation_52[0][0]']
#
#  batch_normalization_37 (Ba  (None, 256, 256, 16)         64        ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 128, 128, 16)         0         ['activation_53[0][0]']
#  g2D)
#
#  dropout_8 (Dropout)         (None, 128, 128, 16)         0         ['max_pooling2d_8[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 128, 128, 32)         12832     ['dropout_8[0][0]']
#
#  batch_normalization_38 (Ba  (None, 128, 128, 32)         128       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 128, 128, 32)         25632     ['activation_54[0][0]']
#
#  batch_normalization_39 (Ba  (None, 128, 128, 32)         128       ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  max_pooling2d_9 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_55[0][0]']
#  g2D)
#
#  dropout_9 (Dropout)         (None, 64, 64, 32)           0         ['max_pooling2d_9[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 64, 64, 64)           51264     ['dropout_9[0][0]']
#
#  batch_normalization_40 (Ba  (None, 64, 64, 64)           256       ['conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_67 (Conv2D)          (None, 64, 64, 64)           102464    ['activation_56[0][0]']
#
#  batch_normalization_41 (Ba  (None, 64, 64, 64)           256       ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  max_pooling2d_10 (MaxPooli  (None, 32, 32, 64)           0         ['activation_57[0][0]']
#  ng2D)
#
#  dropout_10 (Dropout)        (None, 32, 32, 64)           0         ['max_pooling2d_10[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 32, 32, 128)          204928    ['dropout_10[0][0]']
#
#  batch_normalization_42 (Ba  (None, 32, 32, 128)          512       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_69 (Conv2D)          (None, 32, 32, 128)          409728    ['activation_58[0][0]']
#
#  batch_normalization_43 (Ba  (None, 32, 32, 128)          512       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  max_pooling2d_11 (MaxPooli  (None, 16, 16, 128)          0         ['activation_59[0][0]']
#  ng2D)
#
#  dropout_11 (Dropout)        (None, 16, 16, 128)          0         ['max_pooling2d_11[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 16, 16, 256)          819456    ['dropout_11[0][0]']
#
#  batch_normalization_44 (Ba  (None, 16, 16, 256)          1024      ['conv2d_70[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_71 (Conv2D)          (None, 16, 16, 256)          1638656   ['activation_60[0][0]']
#
#  batch_normalization_45 (Ba  (None, 16, 16, 256)          1024      ['conv2d_71[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_72 (Conv2D)          (None, 16, 16, 128)          65664     ['activation_59[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 16, 16, 128)          32896     ['activation_61[0][0]']
#
#  add_8 (Add)                 (None, 16, 16, 128)          0         ['conv2d_72[0][0]',
#                                                                      'conv2d_73[0][0]']
#
#  activation_62 (Activation)  (None, 16, 16, 128)          0         ['add_8[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 16, 16, 1)            129       ['activation_62[0][0]']
#
#  activation_63 (Activation)  (None, 16, 16, 1)            0         ['conv2d_74[0][0]']
#
#  up_sampling2d_8 (UpSamplin  (None, 32, 32, 1)            0         ['activation_63[0][0]']
#  g2D)
#
#  conv2d_transpose_8 (Conv2D  (None, 32, 32, 128)          819328    ['activation_61[0][0]']
#  Transpose)
#
#  multiply_8 (Multiply)       (None, 32, 32, 128)          0         ['activation_59[0][0]',
#                                                                      'up_sampling2d_8[0][0]']
#
#  concatenate_8 (Concatenate  (None, 32, 32, 256)          0         ['conv2d_transpose_8[0][0]',
#  )                                                                   'multiply_8[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 32, 32, 128)          819328    ['concatenate_8[0][0]']
#
#  batch_normalization_46 (Ba  (None, 32, 32, 128)          512       ['conv2d_75[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_76 (Conv2D)          (None, 32, 32, 128)          409728    ['activation_64[0][0]']
#
#  batch_normalization_47 (Ba  (None, 32, 32, 128)          512       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_65 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_77 (Conv2D)          (None, 32, 32, 64)           16448     ['activation_57[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 32, 32, 64)           8256      ['activation_65[0][0]']
#
#  add_9 (Add)                 (None, 32, 32, 64)           0         ['conv2d_77[0][0]',
#                                                                      'conv2d_78[0][0]']
#
#  activation_66 (Activation)  (None, 32, 32, 64)           0         ['add_9[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 32, 32, 1)            65        ['activation_66[0][0]']
#
#  activation_67 (Activation)  (None, 32, 32, 1)            0         ['conv2d_79[0][0]']
#
#  up_sampling2d_9 (UpSamplin  (None, 64, 64, 1)            0         ['activation_67[0][0]']
#  g2D)
#
#  conv2d_transpose_9 (Conv2D  (None, 64, 64, 64)           204864    ['activation_65[0][0]']
#  Transpose)
#
#  multiply_9 (Multiply)       (None, 64, 64, 64)           0         ['activation_57[0][0]',
#                                                                      'up_sampling2d_9[0][0]']
#
#  concatenate_9 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_9[0][0]',
#  )                                                                   'multiply_9[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 64, 64, 64)           204864    ['concatenate_9[0][0]']
#
#  batch_normalization_48 (Ba  (None, 64, 64, 64)           256       ['conv2d_80[0][0]']
#  tchNormalization)
#
#  activation_68 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_81 (Conv2D)          (None, 64, 64, 64)           102464    ['activation_68[0][0]']
#
#  batch_normalization_49 (Ba  (None, 64, 64, 64)           256       ['conv2d_81[0][0]']
#  tchNormalization)
#
#  activation_69 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 64, 64, 32)           4128      ['activation_55[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 64, 64, 32)           2080      ['activation_69[0][0]']
#
#  add_10 (Add)                (None, 64, 64, 32)           0         ['conv2d_82[0][0]',
#                                                                      'conv2d_83[0][0]']
#
#  activation_70 (Activation)  (None, 64, 64, 32)           0         ['add_10[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 64, 64, 1)            33        ['activation_70[0][0]']
#
#  activation_71 (Activation)  (None, 64, 64, 1)            0         ['conv2d_84[0][0]']
#
#  up_sampling2d_10 (UpSampli  (None, 128, 128, 1)          0         ['activation_71[0][0]']
#  ng2D)
#
#  conv2d_transpose_10 (Conv2  (None, 128, 128, 32)         51232     ['activation_69[0][0]']
#  DTranspose)
#
#  multiply_10 (Multiply)      (None, 128, 128, 32)         0         ['activation_55[0][0]',
#                                                                      'up_sampling2d_10[0][0]']
#
#  concatenate_10 (Concatenat  (None, 128, 128, 64)         0         ['conv2d_transpose_10[0][0]',
#  e)                                                                  'multiply_10[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 128, 128, 32)         51232     ['concatenate_10[0][0]']
#
#  batch_normalization_50 (Ba  (None, 128, 128, 32)         128       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_72 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 128, 128, 32)         25632     ['activation_72[0][0]']
#
#  batch_normalization_51 (Ba  (None, 128, 128, 32)         128       ['conv2d_86[0][0]']
#  tchNormalization)
#
#  activation_73 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 128, 128, 16)         1040      ['activation_53[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 128, 128, 16)         528       ['activation_73[0][0]']
#
#  add_11 (Add)                (None, 128, 128, 16)         0         ['conv2d_87[0][0]',
#                                                                      'conv2d_88[0][0]']
#
#  activation_74 (Activation)  (None, 128, 128, 16)         0         ['add_11[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 128, 128, 1)          17        ['activation_74[0][0]']
#
#  activation_75 (Activation)  (None, 128, 128, 1)          0         ['conv2d_89[0][0]']
#
#  up_sampling2d_11 (UpSampli  (None, 256, 256, 1)          0         ['activation_75[0][0]']
#  ng2D)
#
#  conv2d_transpose_11 (Conv2  (None, 256, 256, 16)         12816     ['activation_73[0][0]']
#  DTranspose)
#
#  multiply_11 (Multiply)      (None, 256, 256, 16)         0         ['activation_53[0][0]',
#                                                                      'up_sampling2d_11[0][0]']
#
#  concatenate_11 (Concatenat  (None, 256, 256, 32)         0         ['conv2d_transpose_11[0][0]',
#  e)                                                                  'multiply_11[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 256, 256, 16)         12816     ['concatenate_11[0][0]']
#
#  batch_normalization_52 (Ba  (None, 256, 256, 16)         64        ['conv2d_90[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv2d_91 (Conv2D)          (None, 256, 256, 16)         6416      ['activation_76[0][0]']
#
#  batch_normalization_53 (Ba  (None, 256, 256, 16)         64        ['conv2d_91[0][0]']
#  tchNormalization)
#
#  activation_77 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_92 (Conv2D)          (None, 256, 256, 1)          17        ['activation_77[0][0]']
#
# ==================================================================================================
# Total params: 6130501 (23.39 MB)
# Trainable params: 6127557 (23.37 MB)
# Non-trainable params: 2944 (11.50 KB)
# __________________________________________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
print(len(images_train))
# Out:
# 26860

# %%
print('---model 훈련 시작---')
history = model.fit_generator(
    train_generator,
    steps_per_epoch=len(images_train) // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=len(images_validation) // BATCH_SIZE,
    callbacks=[checkpoint, es],
    epochs=EPOCHS,
    workers=WORKERS,
    initial_epoch=INITIAL_EPOCH
)
print('---model 훈련 종료---')
# Out:
# ---model 훈련 시작---
# Epoch 1/300
# 2024-03-19 12:35:46.265503: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/dropout_8/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-03-19 12:35:56.921400: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.00GiB (rounded to 1073741824)requested by op model_2/conv2d_62/Conv2D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-19 12:35:56.921560: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-19 12:35:56.921591: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 469, Chunks in use: 469. 117.2KiB allocated for chunks. 117.2KiB in use in bin. 50.0KiB client-requested in use in bin.
# 2024-03-19 12:35:56.921603: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 112, Chunks in use: 112. 57.0KiB allocated for chunks. 57.0KiB in use in bin. 56.0KiB client-requested in use in bin.
# 2024-03-19 12:35:56.921613: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 47, Chunks in use: 46. 49.8KiB allocated for chunks. 48.0KiB in use in bin. 46.0KiB client-requested in use in bin.
# 2024-03-19 12:35:56.921623: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 6, Chunks in use: 6. 12.0KiB allocated for chunks. 12.0KiB in use in bin. 12.0KiB client-requested in use in bin.
# 2024-03-19 12:35:56.921633: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 8, Chunks in use: 8. 33.5KiB allocated for chunks. 33.5KiB in use in bin. 33.4KiB client-requested in use in bin.
# 2024-03-19 12:35:56.921642: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 8, Chunks in use: 8. 72.5KiB allocated for chunks. 72.5KiB in use in bin. 68.3KiB client-requested in use in bin.
# 2024-03-19 12:35:56.921653: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 17, Chunks in use: 17. 363.0KiB allocated for chunks. 363.0KiB in use in bin. 352.2KiB client-requested in use in bin.
# 2024-03-19 12:35:56.921662: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 26, Chunks in use: 26. 1.12MiB allocated for chunks. 1.12MiB in use in bin. 1.09MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921671: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 17, Chunks in use: 17. 1.45MiB allocated for chunks. 1.45MiB in use in bin. 1.40MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921681: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 23, Chunks in use: 23. 4.02MiB allocated for chunks. 4.02MiB in use in bin. 3.88MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921693: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 270, Chunks in use: 268. 69.51MiB allocated for chunks. 69.01MiB in use in bin. 68.10MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921704: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 261, Chunks in use: 261. 196.99MiB allocated for chunks. 196.99MiB in use in bin. 195.23MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921714: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 23, Chunks in use: 23. 31.45MiB allocated for chunks. 31.45MiB in use in bin. 27.00MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921724: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 18, Chunks in use: 18. 56.25MiB allocated for chunks. 56.25MiB in use in bin. 56.25MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 6, Chunks in use: 6. 37.50MiB allocated for chunks. 37.50MiB in use in bin. 37.50MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921744: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-19 12:35:56.921755: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-19 12:35:56.921765: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-19 12:35:56.921777: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 1, Chunks in use: 1. 110.00MiB allocated for chunks. 110.00MiB in use in bin. 64.00MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921787: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 2, Chunks in use: 1. 372.39MiB allocated for chunks. 192.00MiB in use in bin. 192.00MiB client-requested in use in bin.
# 2024-03-19 12:35:56.921795: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-19 12:35:56.921804: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 1.00GiB was 256.00MiB, Chunk State:
# 2024-03-19 12:35:56.921812: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 924188672
# 2024-03-19 12:35:56.921822: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000000 of size 1280 next 1
# 2024-03-19 12:35:56.921830: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000500 of size 256 next 2
# 2024-03-19 12:35:56.921837: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000600 of size 256 next 3
# 2024-03-19 12:35:56.921844: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000700 of size 256 next 5
# 2024-03-19 12:35:56.921851: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000800 of size 256 next 6
# 2024-03-19 12:35:56.921858: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000900 of size 256 next 4
# 2024-03-19 12:35:56.921866: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000a00 of size 256 next 563
# 2024-03-19 12:35:56.921873: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000b00 of size 256 next 572
# 2024-03-19 12:35:56.921880: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18000c00 of size 256 next 576
# 2024-03-19 12:35:56.921888: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f1c18
I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 115343360 totalling 110.00MiB
# 2024-03-19 12:35:56.932251: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 201326592 totalling 192.00MiB
# 2024-03-19 12:35:56.932255: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 700.48MiB
# 2024-03-19 12:35:56.932259: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 924188672 memory_limit_: 924188672 available bytes: 0 curr_region_allocation_bytes_: 1848377344
# 2024-03-19 12:35:56.932267: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                       924188672
# InUse:                       734510336
# MaxInUse:                    740539648
# NumAllocs:                      336982
# MaxAllocSize:                201326592
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-19 12:35:56.932295: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] **********************************xxxxx*****************************************____________________
# 2024-03-19 12:35:56.932315: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at conv_ops_impl.h:679 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[256,256,256,16] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[18], line 2
#       1 print('---model 훈련 시작---')
# ----> 2 history = model.fit_generator(
#       3     train_generator,
#       4     steps_per_epoch=len(images_train) // BATCH_SIZE,
#       5     validation_data=validation_generator,
#       6     validation_steps=len(images_validation) // BATCH_SIZE,
#       7     callbacks=[checkpoint, es],
#       8     epochs=EPOCHS,
#       9     workers=WORKERS,
#      10     initial_epoch=INITIAL_EPOCH
#      11 )
#      12 print('---model 훈련 종료---')
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:2913, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2901 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2902
#    2903 DEPRECATED:
#    2904   `Model.fit` now supports generators, so there is no longer any need to
#    2905   use this endpoint.
#    2906 """
#    2907 warnings.warn(
#    2908     "`Model.fit_generator` is deprecated and "
#    2909     "will be removed in a future version. "
#    2910     "Please use `Model.fit`, which supports generators.",
#    2911     stacklevel=2,
#    2912 )
# -> 2913 return self.fit(
#    2914     generator,
#    2915     steps_per_epoch=steps_per_epoch,
#    2916     epochs=epochs,
#    2917     verbose=verbose,
#    2918     callbacks=callbacks,
#    2919     validation_data=validation_data,
#    2920     validation_steps=validation_steps,
#    2921     validation_freq=validation_freq,
#    2922     class_weight=class_weight,
#    2923     max_queue_size=max_queue_size,
#    2924     workers=workers,
#    2925     use_multiprocessing=use_multiprocessing,
#    2926     shuffle=shuffle,
#    2927     initial_epoch=initial_epoch,
#    2928 )
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node model_2/conv2d_62/Conv2D defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 1053, in launch_instance
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 529, in dispatch_queue
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 518, in process_one
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 424, in dispatch_shell
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 766, in execute_request
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 429, in do_execute
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3046, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3101, in _run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3306, in run_cell_async
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3488, in run_ast_nodes
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3548, in run_code
#
#   File "/tmp/ipykernel_988/1217957796.py", line 2, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 2913, in fit_generator
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 1150, in train_step
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py", line 290, in call
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py", line 262, in convolution_op
#
# OOM when allocating tensor with shape[256,256,256,16] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model_2/conv2d_62/Conv2D}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_708131]

# %% [markdown]
# 압축을 잘못하면... 아래 코드를 사용하세요

# %%
# Import necessary libraries
# from google.colab import drive
import glob
import os

# This will prompt for authorization to access your Google Drive
# drive.mount('/content/drive')

# Define the directory to search in
search_dir = '/content/drive/My Drive/'

# Define the pattern to search for
file_pattern = 'train_img_*.tif'

# Construct the full search path
search_path = os.path.join(search_dir, file_pattern)

# Find all files matching the pattern
matching_files = glob.glob(search_path)

# Optional: Print the files to be deleted (for verification)


# Uncomment the next lines to delete the files
for file in matching_files:
    os.remove(file)
    print(f"Deleted {file}")

print("Deletion complete.")
# Out:
# Deletion complete.
